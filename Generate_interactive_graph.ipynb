# %%
! pip install numpy
! pip install pandas
! pip install matplotlib
! pip install Ipython
! pip install ipympl
# Out:
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 2.2/2.2 MB 17.7 MB/s eta 0:00:00
# ...
#
#    ---------------------------------------- 0/4 [widgetsnbextension]
#    ---------------------------------------- 0/4 [widgetsnbextension]
#    ---------------------------------------- 0/4 [widgetsnbextension]
#    ---------------------------------------- 0/4 [widgetsnbextension]
#    ---------------------------------------- 0/4 [widgetsnbextension]
#    ---------------------------------------- 0/4 [widgetsnbextension]
#    ---------- ----------------------------- 1/4 [jupyterlab_widgets]
#    -------------------- ------------------- 2/4 [ipywidgets]
#    -------------------- ------------------- 2/4 [ipywidgets]
#    -------------------- ------------------- 2/4 [ipywidgets]
#    -------------------- ------------------- 2/4 [ipywidgets]
#    -------------------- ------------------- 2/4 [ipywidgets]
# ...

# %%
# %matplotlib widget
import matplotlib
print(matplotlib.get_backend())
# Out:
# widget

# %%
#Import Relevant Modules
import re
from datetime import datetime, date
from time import sleep
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import glob
from IPython.display import clear_output
import matplotlib.dates as mdates
import matplotlib.gridspec as gridspec
import matplotlib.ticker as ticker
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.backend_bases import MouseEvent

# %%
def getCCSPowerData(filename, PSU_ID):
    '''
    Extract CCS power supply data from txt file

    @param:
        filename -> str
    
    @return:
        3D list of time and CCS voltage/current -> list
    '''
    
    data = []                          
    powerPattern = re.compile(r'\[(\d{2}:\d{2}:\d{2})\].*?DEBUG: Power supply ' + PSU_ID + r' readings - Voltage: (\d*.\d*)V, Current: (\d*.\d*)A', re.I)
    
    with open(filename, "r") as f:
        for line in f:
            p = powerPattern.search(line)
            if p:
                time_str = p.group(1)
                voltage = p.group(2)
                current = p.group(3)
                log_time = datetime.strptime(time_str, "%H:%M:%S").time()

                data.append((time_str, voltage, current))
    return data

# %%
def getHVData(filename):
    '''
    Extract pressure data from txt file

    @param:
        filename -> str
    
    @return:
        2D list of time and HV current -> list
    '''
    
    data = []                          
    pressure_pattern = re.compile(r'\[\d{4}-\d{2}-\d{2} (.*?)\] Set: -?(\d*) V,  HV: -?(\d*) V,  I: -?([\d\.]*) mA', re.I)
    
    with open(filename, "r") as f:
        for line in f:
            p = pressure_pattern.search(line)
            if p:
                time_str = p.group(1)
                a0 = (float(p.group(3))/3000)*5
                a1 = (float(p.group(2))/3000)*5
                a2 = (float(p.group(4))/10)*5
                log_time = datetime.strptime(time_str, "%H:%M:%S.%f").time()

                data.append((time_str, a0, a1, a2))
    return data

# %%
def getCCSaTempData(filename):
    '''
    Extract CCS temperature data from txt file

    @param:
        filename -> str
    
    @return:
        2D list of Time and Pressure -> list
    '''
    
    data = []                          
    temp_pattern = re.compile(r'\[(\d{2}:\d{2}:\d{2})\].*?INFO: Unit 1 Temperature: (\d*.\d*) C', re.I)
    
    with open(filename, "r") as f:
        for line in f:
            p = temp_pattern.search(line)
            if p:
                time_str = p.group(1)
                temp = p.group(2)
                log_time = datetime.strptime(time_str, "%H:%M:%S").time()

                data.append((time_str, temp))
    return data

# %%
def getCCSbTempData(filename):
    '''
    Extract CCS temperature data from txt file

    @param:
        filename -> str
    
    @return:
        2D list of Time and Pressure -> list
    '''
    
    data = []                          
    temp_pattern = re.compile(r'\[(\d{2}:\d{2}:\d{2})\].*?INFO: Unit 2 Temperature: (\d*.\d*) C', re.I)
    
    with open(filename, "r") as f:
        for line in f:
            p = temp_pattern.search(line)
            if p:
                time_str = p.group(1)
                temp = p.group(2)
                log_time = datetime.strptime(time_str, "%H:%M:%S").time()

                data.append((time_str, temp))
    return data

# %%
def getCCScTempData(filename):
    '''
    Extract CCS temperature data from txt file

    @param:
        filename -> str
    
    @return:
        2D list of Time and Pressure -> list
    '''
    
    data = []                          
    temp_pattern = re.compile(r'\[(\d{2}:\d{2}:\d{2})\].*?INFO: Unit 3 Temperature: (\d*.\d*) C', re.I)
    
    with open(filename, "r") as f:
        for line in f:
            p = temp_pattern.search(line)
            if p:
                time_str = p.group(1)
                temp = p.group(2)
                log_time = datetime.strptime(time_str, "%H:%M:%S").time()

                data.append((time_str, temp))
    return data

# %%
def getPressureData(filename):
    '''
    Extract pressure data from txt file

    @param:
        filename -> str
    
    @return:
        2D list of Time and Pressure -> list
    '''
    
    data = []                          
    pressure_pattern = re.compile(r'\[(\d{2}:\d{2}:\d{2})\].*?pressure:\s*([0-9.]+E[-+]?\d+)', re.I)
    
    with open(filename, "r") as f:
        for line in f:
            p = pressure_pattern.search(line)
            if p:
                time_str = p.group(1)
                pressure = p.group(2)
                log_time = datetime.strptime(time_str, "%H:%M:%S").time()

                data.append((time_str, pressure))
    return data

# %%
def getPMONData(filename):
    '''
    Extract PMON Temperature data from txt file

    @param:
        filename -> str
    @return:
        list with data from each PMON
    '''
    
    data = [] 
    pmon_pattern = re.compile(r'\[(\d{2}:\d{2}:\d{2})\].*?PMON\s+temps:\s*(\{[^}]+\})', re.I)
    with open(filename, "r") as f:
        for line in f:
            p = pmon_pattern.search(line)
            if p:
                time_str = p.group(1)
                log_time = datetime.strptime(time_str, "%H:%M:%S").time()
                
                pmon_dict = eval(p.group(2))
                pmon_1 = pmon_dict[1]
                pmon_2 = pmon_dict[2]
                pmon_3 = pmon_dict[3]
                pmon_4 = pmon_dict[4]
                pmon_5 = pmon_dict[5]
                pmon_6 = pmon_dict[6]

                data.append((time_str, pmon_1, pmon_2, pmon_3, pmon_4, pmon_5, pmon_6))
    return data

# %%
def createCCSPowerCSV(ccs_data, filename):
    '''

    @param:
    ccs_data: list of CCS power supply data -> list
    '''
    with open(filename, 'w', newline='') as out:
        writer = csv.writer(out)
        writer.writerow(['Time', 'Voltage (V)', 'Current (A)'])   # header
        writer.writerows(ccs_data)

    #print(f'{len(ccs_data)} rows written to ccs_psu_log-' + psuID + '-' + str(date) + '.csv')

# %%
def createCCSaTempCSV(ccs_data, filename):
    '''

    @param:
    ccs_data: list of data -> list
    '''
    #Using 'w' to overwrite existing
    with open(filename, 'w', newline='') as out:
        writer = csv.writer(out)
        writer.writerow(['Time', 'Temperature (C)'])   # header
        writer.writerows(ccs_data)
        
    #print(f'{len(pressure_data)} rows written to CCS_A_temp_log-'+ str(date) + '.csv')

# %%
def createCCSbTempCSV(ccs_data, filename):
    '''

    @param:
    ccs_data: list of data -> list
    '''
    #Using 'w' to overwrite existing
    with open(filename, 'w', newline='') as out:
        writer = csv.writer(out)
        writer.writerow(['Time', 'Temperature (C)'])   # header
        writer.writerows(ccs_data)
        
    #print(f'{len(pressure_data)} rows written to CCS_B_temp_log-'+ str(date) + '.csv')

# %%
def createCCScTempCSV(ccs_data, filename):
    '''

    @param:
    ccs_data: list of data -> list
    '''
    #Using 'w' to overwrite existing
    with open(filename, 'w', newline='') as out:
        writer = csv.writer(out)
        writer.writerow(['Time', 'Temperature (C)'])   # header
        writer.writerows(ccs_data)
        
    #print(f'{len(pressure_data)} rows written to CCS_C_temp_log-'+ str(date) + '.csv')

# %%
def createHvCSV(hv_data, filename):
    '''

    @param:
    pressure_data: list of data -> list
    '''
    with open(filename, 'w', newline='') as out:
        writer = csv.writer(out)
        writer.writerow(['Time', 'Read voltage (V)', 'Set voltage (V)', 'Current (mA)'])   # header
        writer.writerows(hv_data)

    #print(f'{len(hv_data)} rows written to HV_log-'+ str(date) + '.csv')

# %%
def createPressureCSV(pressure_data, filename):
    '''

    @param:
    pressure_data: list of data -> list
    '''
    #Using 'w' to overwrite existing
    with open(filename, 'w', newline='') as out:
        writer = csv.writer(out)
        writer.writerow(['Time', 'Pressure (mbar)'])   # header
        writer.writerows(pressure_data)
        
    #print(f'{len(pressure_data)} rows written to pressure_log-'+ str(date) + '.csv')

# %%
def createPMONCSV(pmon_data, filename):
    '''

    @param:
    pmon_data: list of data -> list
    '''
    with open(filename, 'w', newline='') as out:
        writer = csv.writer(out)
        writer.writerow(['Time', 'PMON 1', 'PMON_2', 'PMON_3', 'PMON_4', 'PMON_5', 'PMON_6'])   # header
        writer.writerows(pmon_data)

    #print(f'{len(pmon_data)} rows written to pmon_log-' + str(date) + '.csv')

# %%
def getGraph(pmon_raw, pressure_raw, hv_3kv_raw, CCSaTemp_raw, CCSbTemp_raw, CCScTemp_raw, CCSaPSU_raw, 
             CCSbPSU_raw, CCScPSU_raw, ccs_V = True, ccs_I = True, hv3kv_V = True, hv3kv_I = True,
             start_time='00:00:01', end_time='23:59:59'):
    '''
    Displays Graph of PMON, pressure, and HV current (beam current) using multiple panes in one graph window
    Takes 

    args:
        pmon data : list of data -> list
        pressure_data : list of data -> list
        hvCurrent_data : list of data -> list
    
    '''

    # Convert pmon data to DataFrame
    pmon_df = pd.DataFrame(pmon_raw, columns=["Time", "PMON_1", "PMON_2", "PMON_3", "PMON_4", "PMON_5", "PMON_6"])
    pmon_df['Time'] = pd.to_datetime(pmon_df['Time'].astype(str), format = "mixed")
    
    # Filter by time range
    start_dt = pd.to_datetime(start_time)
    end_dt = pd.to_datetime(end_time)
    pmon_df = pmon_df[(pmon_df["Time"] >= start_dt) & (pmon_df["Time"] <= end_dt)]

    # Convert to float and handle missing/disconnected
    ports = ['PMON_1', 'PMON_2', 'PMON_3', 'PMON_4', 'PMON_5', 'PMON_6']
    for col in ports:
        pmon_df[col] = pd.to_numeric(pmon_df[col], errors='coerce').ffill()

    # Convert all other datasets to DataFrames and convert values to floats
    def to_df(data, columns):
        df = pd.DataFrame(data, columns=columns)
        df['Time'] = pd.to_datetime(df['Time'].astype(str), format = "mixed")
        for col in range(1, len(columns)) :
            df[columns[col]] = pd.to_numeric(df[columns[col]])
        return df[(df["Time"] >= start_dt) & (df["Time"] <= end_dt)]

    pressure_df = to_df(pressure_raw, ["Time", "Pressure (mbar)"])
    hv_df = to_df(hv_3kv_raw, ["Time", "Read voltage (V)", "Set voltage (V)", "Current (mA)"])
    ccs_a_temp_df = to_df(CCSaTemp_raw, ["Time", "Temperature (C)"])
    ccs_b_temp_df = to_df(CCSbTemp_raw, ["Time", "Temperature (C)"])
    ccs_c_temp_df = to_df(CCScTemp_raw, ["Time", "Temperature (C)"])
    ccs_a_psu_df = to_df(CCSaPSU_raw, ["Time", "Voltage (V)", "Current (A)"])
    ccs_b_psu_df = to_df(CCSbPSU_raw, ["Time", "Voltage (V)", "Current (A)"])
    ccs_c_psu_df = to_df(CCScPSU_raw, ["Time", "Voltage (V)", "Current (A)"])

    # Count the number of non-empty data frames we have
    numPlots = 0
    
    if not(pmon_df.empty) :
        numPlots += 1

    if (not(ccs_a_temp_df.empty)) and (not(ccs_b_temp_df.empty)) and (not(ccs_c_temp_df.empty)) :
        numPlots+=1

    if not(pressure_df.empty) :
        numPlots+=1

    if not(hv_df.empty) :
        if(hv3kv_V) :
            numPlots +=1
        if(hv3kv_I) :
            numPlots += 1

    if (not(ccs_a_psu_df.empty)) and (not(ccs_b_psu_df.empty)) and (not(ccs_c_psu_df.empty)) :
        if(ccs_V) :
            numPlots +=1
        if(ccs_I) :
            numPlots += 1

    ###################
    # Graph the data! #
    ###################
    curr_plot_num = 0
    
    # Lookup table for numPlots vs num_y_ticks
    num_y_ticks = [
        0, # 0 plots
        0, # 1 plot (can't do just 1 plot with this method)
        20, # 2 plots
        10, # 3 plots
        5, # 4 plots
        3, # 5 plots
        3 # 6 plots
    ] 
    

    # Set graph details, including figure aspect ratio and graph height ratios
    fig, axs = plt.subplots(numPlots, 1, figsize=(18, 9), sharex=True)

    # declare lists for graph lines for interactive use
    lines_pmon = []
    lines_ccs_temp = []
    lines_pressure = []
    lines_3kv_V = []
    lines_3kv_I = []
    lines_ccs_V = []
    lines_ccs_I = []
    axis_line_count = []
    


    # PMON Temperatures
    if not(pmon_df.empty) :
        for col in ports:
            label = col + ' (' +  pmon_df[col].iloc[-1].astype(str)+ '°C)'
            lines_pmon.append(axs[curr_plot_num].plot(pmon_df["Time"], pmon_df[col], label=label)[0])

        axs[curr_plot_num].set_ylabel("PMON Temperatures")
        axs[curr_plot_num].legend(loc="upper left")
        axs[curr_plot_num].grid(True)
        axs[curr_plot_num].yaxis.set_major_locator(ticker.MaxNLocator(nbins=num_y_ticks[numPlots]))
        axis_line_count.append(6)
        curr_plot_num += 1
        

    # CCS Temperature plot
    if (not(ccs_a_temp_df.empty)) and (not(ccs_b_temp_df.empty)) and (not(ccs_c_temp_df.empty)) :
        ccsA_label = 'CCS A (' + ccs_a_temp_df['Temperature (C)'].iloc[-1].astype(str) + '°C)'
        ccsB_label = 'CCS B (' + ccs_b_temp_df['Temperature (C)'].iloc[-1].astype(str) + '°C)'
        ccsC_label = 'CCS C (' + ccs_c_temp_df['Temperature (C)'].iloc[-1].astype(str) + '°C)'

        lines_ccs_temp.append(axs[curr_plot_num].plot(ccs_a_temp_df['Time'], 
                                                      ccs_a_temp_df['Temperature (C)'], label=ccsA_label)[0])
        lines_ccs_temp.append(axs[curr_plot_num].plot(ccs_b_temp_df['Time'], 
                                                      ccs_b_temp_df['Temperature (C)'], label=ccsB_label)[0])
        lines_ccs_temp.append(axs[curr_plot_num].plot(ccs_c_temp_df['Time'], 
                                                      ccs_c_temp_df['Temperature (C)'], label=ccsC_label)[0])

        axs[curr_plot_num].set_ylabel('CCS Temperatures')
        axs[curr_plot_num].legend(loc='upper left')
        axs[curr_plot_num].grid(True)
        axs[curr_plot_num].yaxis.set_major_locator(ticker.MaxNLocator(nbins=num_y_ticks[numPlots]))
        axis_line_count.append(3)
        curr_plot_num += 1
    

    # --- Pressure plot ---
    if not(pressure_df.empty) :
        pressureLabel = 'Pressure (' + pressure_df['Pressure (mbar)'].iloc[-1].astype(str) + 'mbar)'

        lines_pressure.append(axs[curr_plot_num].plot(pressure_df['Time'], 
                                                      pressure_df['Pressure (mbar)'], label = pressureLabel)[0])

        axs[curr_plot_num].set_ylabel('Pressure (mbar)')
        axs[curr_plot_num].legend(loc='upper left')
        axs[curr_plot_num].grid(True)
        axs[curr_plot_num].yaxis.set_major_locator(ticker.MaxNLocator(nbins=num_y_ticks[numPlots]))
        axis_line_count.append(1)
        curr_plot_num += 1

    # --- HV monitor 3kV plot ---
    if not(hv_df.empty) and hv3kv_V :
        readVoltageLabel = 'Read voltage (' + hv_df['Read voltage (V)'].iloc[-1].astype(str) + 'V)'
        setVoltageLabel = 'Set voltage (' + hv_df['Set voltage (V)'].iloc[-1].astype(str) + 'V)'
        

        lines_3kv_V.append(axs[curr_plot_num].plot(hv_df['Time'], 
                                                   hv_df['Read voltage (V)'], label=readVoltageLabel)[0])
        lines_3kv_V.append(axs[curr_plot_num].plot(hv_df['Time'], 
                                                   hv_df['Set voltage (V)'], label=setVoltageLabel)[0])
        
        axs[curr_plot_num].set_ylabel('3kV PSU voltage')
        axs[curr_plot_num].legend(loc='upper left')
        axs[curr_plot_num].grid(True)
        axs[curr_plot_num].yaxis.set_major_locator(ticker.MaxNLocator(nbins=num_y_ticks[numPlots]))
        axis_line_count.append(2)
        curr_plot_num += 1

    if not(hv_df.empty) and hv3kv_I :

        readCurrentLabel = 'Read current (' + hv_df['Current (mA)'].iloc[-1].astype(str) + 'mA)'
        lines_3kv_I.append(axs[curr_plot_num].plot(hv_df['Time'], 
                                                   hv_df['Current (mA)'], label=readCurrentLabel)[0])

        axs[curr_plot_num].set_ylabel('3kV PSU current')
        axs[curr_plot_num].legend(loc='upper left')
        axs[curr_plot_num].grid(True)
        axs[curr_plot_num].yaxis.set_major_locator(ticker.MaxNLocator(nbins=num_y_ticks[numPlots]))
        axis_line_count.append(1)
        curr_plot_num += 1

    # CCS voltage plot
    if (not(ccs_a_psu_df.empty)) and (not(ccs_b_psu_df.empty)) and (not(ccs_c_psu_df.empty)) and ccs_V :
        ccsA_label = 'CCS A (' + ccs_a_psu_df['Voltage (V)'].iloc[-1].astype(str) + '°C)'
        ccsB_label = 'CCS B (' + ccs_b_psu_df['Voltage (V)'].iloc[-1].astype(str) + '°C)'
        ccsC_label = 'CCS C (' + ccs_c_psu_df['Voltage (V)'].iloc[-1].astype(str) + '°C)'

        lines_ccs_V.append(axs[curr_plot_num].plot(ccs_a_psu_df['Time'], 
                                                   ccs_a_psu_df['Voltage (V)'], label=ccsA_label)[0])
        lines_ccs_V.append(axs[curr_plot_num].plot(ccs_b_psu_df['Time'], 
                                                   ccs_b_psu_df['Voltage (V)'], label=ccsB_label)[0])
        lines_ccs_V.append(axs[curr_plot_num].plot(ccs_c_psu_df['Time'], 
                                                   ccs_c_psu_df['Voltage (V)'], label=ccsC_label)[0])

        axs[curr_plot_num].set_ylabel('CCS Voltages')
        axs[curr_plot_num].legend(loc='upper left')
        axs[curr_plot_num].grid(True)
        axs[curr_plot_num].yaxis.set_major_locator(ticker.MaxNLocator(nbins=num_y_ticks[numPlots]))
        axis_line_count.append(3)
        curr_plot_num += 1

    # CCS current plot
    if (not(ccs_a_psu_df.empty)) and (not(ccs_b_psu_df.empty)) and (not(ccs_c_psu_df.empty)) and ccs_I :
        ccsA_label = 'CCS A (' + ccs_a_psu_df['Current (A)'].iloc[-1].astype(str) + '°C)'
        ccsB_label = 'CCS B (' + ccs_b_psu_df['Current (A)'].iloc[-1].astype(str) + '°C)'
        ccsC_label = 'CCS C (' + ccs_c_psu_df['Current (A)'].iloc[-1].astype(str) + '°C)'

        lines_ccs_I.append(axs[curr_plot_num].plot(ccs_a_psu_df['Time'], 
                                                   ccs_a_psu_df['Current (A)'], label=ccsA_label)[0])
        lines_ccs_I.append(axs[curr_plot_num].plot(ccs_b_psu_df['Time'], 
                                ccs_b_psu_df['Current (A)'], label=ccsB_label)[0])
        lines_ccs_I.append(axs[curr_plot_num].plot(ccs_c_psu_df['Time'], 
                                ccs_c_psu_df['Current (A)'], label=ccsC_label)[0])
        
        axs[curr_plot_num].set_ylabel('CCS Currents')
        axs[curr_plot_num].legend(loc='upper left')
        axs[curr_plot_num].grid(True)
        axs[curr_plot_num].yaxis.set_major_locator(ticker.MaxNLocator(nbins=num_y_ticks[numPlots]))
        axis_line_count.append(3)
        curr_plot_num += 1

    # Format x axis
    axs[numPlots-1].xaxis.set_major_locator(ticker.MaxNLocator(nbins=40))
    axs[numPlots-1].xaxis.set_major_formatter(mdates.DateFormatter('%I:%M:%S'))
    for label in axs[numPlots-1].get_xticklabels():
        label.set_rotation(45)       # Rotate the label
        label.set_ha('right')        # Align the label to the right of the tick mark
    axs[numPlots-1].set_xmargin(0)

    ########################
    # Make it interactive! #
    ########################

    # Note: most of this came from ChatGPT, so although it works, I'm not entirely sure how

    # Create separate annotation boxes for each subplot
    annotators = {}
    annot_list = []
    for x in range(0, numPlots-1) :
        annot_list.append(axs[x].annotate("", xy=(0,0), xytext=(20,20), textcoords="offset points",
                                    bbox=dict(boxstyle="round", fc="white", ec="lightgray", lw=1),
                                    arrowprops=dict(arrowstyle="->")))
        
        # Hide box until later (on click)
        annot_list[x].set_visible(False)
        annotators.update({axs[x]: annot_list[x]})


    # List of all lines and their data
    all_lines = lines_pmon + lines_ccs_temp + lines_pressure + lines_3kv_V + lines_3kv_I + lines_ccs_V + lines_ccs_I
    all_axes= []
    for x in range(0, numPlots-1) :
        axis = axs[x]
        all_axes += [axis]*axis_line_count[x]

    def update_annot(line, ind, ax):
        x, y = line.get_data()
        annot = annotators[ax]  # get the right annot for the subplot
        annot.xy = (x[ind["ind"][0]], y[ind["ind"][0]])  # point to the clicked data
        text = f"{line.get_label()}\n{pd.to_datetime(x[ind['ind'][0]]).strftime('%H:%M:%S')}\n{y[ind['ind'][0]]}"
        annot.set_text(text)  # update the text
        annot.get_bbox_patch().set_alpha(0.8)  # make it visible
        annot.set_visible(True)
        fig.canvas.draw_idle()  # redraw the canvas

    def on_click(event: MouseEvent):
        # Hide all annotations first
        for ann in annotators.values():
            ann.set_visible(False)

        if event.inaxes:  # Only respond if clicked inside an axis
            for line, ax in zip(all_lines, all_axes):
                if ax != event.inaxes:
                    continue
                cont, ind = line.contains(event)  # Check if click is on this line
                if cont:
                    update_annot(line, ind, ax)
                    return
        fig.canvas.draw_idle()

    # Connect click handler with plot
    fig.canvas.mpl_connect("button_press_event", on_click)

    plt.tight_layout(h_pad=0, w_pad=0, rect=[0, 0.03, 1, 0.95])
    plt.show()

# %%
################################
# Generate CSV files from logs #
################################

# # Enter your Ebeam dashboard and Tera Term log files here and comment out the following 4 lines to use a specific file
dashboard_log_file = 'Data samples\log_export_2025-06-09_17-10-43.txt'
teraTerm_log_file = 'Data samples\HV_monitor 2025-06-10.txt'

# # Pick the most recently edited Tera Term log file
# teraTerm_files = glob.glob("C:/Users/Experiment/cbmark_logger/Tera Term logs/*")
# teraTerm_log_file = max(teraTerm_files, key=os.path.getctime)

# # Pick the most recently edited dashboard log file
# dashboard_files = glob.glob("C:/Users/Experiment/EBEAM_dashboard/EBEAM-Dashboard-Logs/*")
# dashboard_log_file = max(dashboard_files, key=os.path.getctime)

# Pick out the file names from the file paths
dashboardFilename = os.path.basename(os.path.splitext(dashboard_log_file)[0])
teraTermFilename = os.path.basename(os.path.splitext(teraTerm_log_file)[0])

pmon_csv = f'CSV files/pmon_log---' + dashboardFilename + '.csv'
pressure_csv = f'CSV files/pressure_log---'+ dashboardFilename + '.csv'
hv_csv = f'CSV files/HV_log---'+ teraTermFilename + '.csv'
CCSaTemp = f'CSV files/CCS_A_temp_log---'+ dashboardFilename + '.csv'
CCSbTemp = f'CSV files/CCS_B_temp_log---'+ dashboardFilename + '.csv'
CCScTemp = f'CSV files/CCS_C_temp_log---'+ dashboardFilename + '.csv'
CCSaPSU = f'CSV files/CCS_A_psu_log---' + dashboardFilename + '.csv'
CCSbPSU = f'CSV files/CCS_B_psu_log---' + dashboardFilename + '.csv'
CCScPSU = f'CSV files/CCS_C_psu_log---' + dashboardFilename + '.csv'

# Create the CSV files
createPMONCSV(getPMONData(dashboard_log_file), pmon_csv)
createPressureCSV(getPressureData(dashboard_log_file), pressure_csv)
createHvCSV(getHVData(teraTerm_log_file), hv_csv)
createCCSaTempCSV(getCCSaTempData(dashboard_log_file), CCSaTemp)
createCCSbTempCSV(getCCSbTempData(dashboard_log_file), CCSbTemp)
createCCScTempCSV(getCCScTempData(dashboard_log_file), CCScTemp)
createCCSPowerCSV(getCCSPowerData(dashboard_log_file, '1'), CCSaPSU)
createCCSPowerCSV(getCCSPowerData(dashboard_log_file, '2'), CCSbPSU)
createCCSPowerCSV(getCCSPowerData(dashboard_log_file, '3'), CCScPSU)

# %%
# Log file location on laptop: 'C:/Users/Experiment/EBEAM_dashboard/EBEAM-Dashboard-Logs/'
# Tera term log file location on laptop: 'C:/Users/Experiment/cbmark_logger/Tera Term logs'

# # Enter your Ebeam dashboard and Tera Term log files here and comment out the following 4 lines to use a specific file
dashboard_log_file = 'Data samples\log_export_2025-06-09_17-10-43.txt'
teraTerm_log_file = 'Data samples\HV_monitor 2025-06-10.txt'
blank_file = 'Data samples\Blank.txt'

run = True
while run :
    run = False
    # # Pick the most recently edited Tera Term log file
    # teraTerm_files = glob.glob("C:/Users/Experiment/cbmark_logger/Tera Term logs/*")
    # teraTerm_log_file = max(teraTerm_files, key=os.path.getctime)

    # # Pick the most recently edited dashboard log file
    # dashboard_files = glob.glob("C:/Users/Experiment/EBEAM_dashboard/EBEAM-Dashboard-Logs/*")
    # dashboard_log_file = max(dashboard_files, key=os.path.getctime)

    # You need to have at least two of these be non-empty for my method of graphing to work
    # To customize the graph, just put a blank file in whichever graph you don't want to display
    pmon_raw = getPMONData(dashboard_log_file)
    pressure_raw = getPressureData(dashboard_log_file)
    hv_3kv_raw = getHVData(teraTerm_log_file)
    CCSaTemp_raw = getCCSaTempData(dashboard_log_file)
    CCSbTemp_raw = getCCSbTempData(dashboard_log_file)
    CCScTemp_raw = getCCScTempData(dashboard_log_file)
    CCSaPSU_raw = getCCSPowerData(dashboard_log_file, '1')
    CCSbPSU_raw = getCCSPowerData(dashboard_log_file, '2')
    CCScPSU_raw = getCCSPowerData(dashboard_log_file, '3')

    # Call the function to generate the graph
    getGraph(pmon_raw, pressure_raw, hv_3kv_raw, CCSaTemp_raw, CCSbTemp_raw, CCScTemp_raw, 
             CCSaPSU_raw, CCSbPSU_raw, CCScPSU_raw)
    clear_output(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
